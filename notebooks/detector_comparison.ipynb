# %%
from utils import *
import pandas as pd 
import numpy as np

# %%
def get_resetter_params(row):
    if "_" in row:
        return float(row.split("_")[-1])
    else:
        return

# %%
df = pd.read_csv("../reports/detector_comparison/v5.csv.zip")
df["accuracy"] *= 100
df["reset_lr"] = df["resetter"].apply(get_resetter_params)
df["resetter"] = df["resetter"].apply(lambda x: x.split("_")[0])

# %%
df_mean = agg_dataframe(
    df[df['resetter'] == "P-KSWIN"],
    cols_to_keep=["dataset", "gamma", "base_lr", "reset_lr"],
)
df_best = get_best_params(
    df_mean,
    params=["gamma", "base_lr", "reset_lr"],
    fixed_params=["dataset"],
    metric="accuracy_mean",
)
df_best
# Out:
#            dataset     gamma  base_lr  reset_lr  seed_mean  seed_std
# 0        Covertype  0.999939  0.25000    1.0000        2.0  1.581139  \
# 1      Electricity  0.999756  0.03125    0.5000        2.0  1.581139
# 2   Insects abrupt  0.999756  0.25000    1.0000        2.0  1.581139
# 3  Insects gradual  0.999939  0.50000    0.5000        2.0  1.581139
# 4    Insects incr.  0.999878  0.25000    0.1250        2.0  1.581139
# 5       RBF abrupt  0.999756  0.25000    0.5000        2.0  1.581139
# 6        RBF incr.  0.999939  0.25000    0.0625        2.0  1.581139
# 7              SEA  0.999756  0.03125    0.5000        2.0  1.581139
#
#    Unnamed: 0_mean  Unnamed: 0_std  batch_size_mean  batch_size_std  ...
# 0     3.242867e+06     1719.839958              4.0             0.0  ...  \
# 1     2.660799e+06      754.397468              4.0             0.0  ...
# 2     1.200590e+06      827.568500              4.0             0.0  ...
# 3     7.844505e+05      404.438885              4.0             0.0  ...
# 4     1.877898e+06      951.521713              4.0             0.0  ...
# 5     7.553312e+04      311.641311              4.0             0.0  ...
# 6     3.264879e+05      350.080904              4.0             0.0  ...
# 7     6.274937e+05      321.999271              4.0             0.0  ...
#
#    step_mean  step_std  runtime_mean  runtime_std  accuracy_mean
# 0    50050.0       0.0      0.012621     0.000256      83.529000  \
# 1    22700.0       0.0      0.012303     0.000094      73.911700
# 2    26450.0       0.0      0.012201     0.000270      71.728030
# 3    12100.0       0.0      0.013571     0.001452      75.420747
# 4    28550.0       0.0      0.012233     0.000184      60.589474
# 5    10050.0       0.0      0.012177     0.000091      94.984000
# 6    10050.0       0.0      0.012242     0.000116      73.724000
# 7    10050.0       0.0      0.012023     0.000126      87.524000
#
#    accuracy_std   lr_mean        lr_std  loss_mean  loss_std
# 0      0.181641  0.249947  1.267490e-06   0.108469  0.001479
# 1      0.429636  0.031212  8.075448e-07   0.523307  0.004602
# 2      0.125727  0.249698  7.877833e-06   0.211204  0.000927
# 3      0.154327  0.499724  4.647804e-06   0.180773  0.000902
# 4      0.223565  0.249366  3.354569e-06   0.268621  0.000979
# 5      0.258732  0.249435  2.325629e-05   0.066471  0.002655
# 6      1.418571  0.249396  1.659723e-05   0.265326  0.008012
# 7      6.159758  0.031211  1.010644e-06   0.286425  0.143804
#
# [8 rows x 24 columns]

# %%
df = df[(df["resetter"] != "P-KSWIN") | (df["reset_lr"] == 0.5)]
df = df[df["gamma"] == 1 - 2**-12]
df = df[["dataset", "resetter", "accuracy", 'base_lr', 'seed']]

# %%
df['resetter'].unique()
# Out:
# array(['P-KSWIN', 'ADWIN', 'KSWIN', 'OneTailedADWIN', 'Ground Truth',
#        'ADWIN Weight Reset'], dtype=object)

# %%
# Define which data to show in table
datasets = [
    "RBF abrupt",
    "RBF incr.",
    "Covertype",
    "Insects abrupt",
    "Electricity",
]
ks = [1, 3]
columns = [(dataset, "accuracy") for dataset in datasets]
for k in ks:
    df = df[df["dataset"].isin(datasets)]
    table = get_topk_results(
        df,
        other_variables=["dataset", "resetter"],
        top_variable="base_lr",
        k=k,
    )
    table = table[["dataset", "resetter", "accuracy_mean", "accuracy_std"]]
    table = col_to_header(table, "dataset", index=["resetter"])
    mask_best = get_best_within_std(
        table, params_fixed=[], metrics=columns, modes="max"
    )
    table = merge_mean_std(table, columns, formats="{:.2f}")
    style = table.style
    style = apply_style_attribute(style, mask=mask_best)
    style.to_latex(f"../pub/tables/lr_resetting_top{k}.tex", hrules=True)

# %%
style
# Out:
# <style type="text/css">
# #T_fa706_row0_col1, #T_fa706_row0_col4, #T_fa706_row2_col0, #T_fa706_row2_col3, #T_fa706_row3_col1, #T_fa706_row3_col2, #T_fa706_row3_col3, #T_fa706_row3_col4, #T_fa706_row4_col1, #T_fa706_row4_col4, #T_fa706_row5_col1, #T_fa706_row5_col2, #T_fa706_row5_col4 {
#   bfseries: ;
# }
# </style>
# <table id="T_fa706">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa706_level0_col0" class="col_heading level0 col0" >RBF abrupt</th>
#       <th id="T_fa706_level0_col1" class="col_heading level0 col1" >RBF incr.</th>
#       <th id="T_fa706_level0_col2" class="col_heading level0 col2" >Covertype</th>
#       <th id="T_fa706_level0_col3" class="col_heading level0 col3" >Insects abrupt</th>
#       <th id="T_fa706_level0_col4" class="col_heading level0 col4" >Electricity</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_fa706_level1_col0" class="col_heading level1 col0" >accuracy</th>
#       <th id="T_fa706_level1_col1" class="col_heading level1 col1" >accuracy</th>
#       <th id="T_fa706_level1_col2" class="col_heading level1 col2" >accuracy</th>
#       <th id="T_fa706_level1_col3" class="col_heading level1 col3" >accuracy</th>
#       <th id="T_fa706_level1_col4" class="col_heading level1 col4" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >resetter</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa706_level0_row0" class="row_heading level0 row0" >ADWIN</th>
#       <td id="T_fa706_row0_col0" class="data row0 col0" >94.28±.37</td>
#       <td id="T_fa706_row0_col1" class="data row0 col1" >69.76±.92</td>
#       <td id="T_fa706_row0_col2" class="data row0 col2" >82.70±.27</td>
#       <td id="T_fa706_row0_col3" class="data row0 col3" >71.27±.14</td>
#       <td id="T_fa706_row0_col4" class="data row0 col4" >73.05±.45</td>
#     </tr>
#     <tr>
#       <th id="T_fa706_level0_row1" class="row_heading level0 row1" >ADWIN Weight Reset</th>
#       <td id="T_fa706_row1_col0" class="data row1 col0" >66.24±.55</td>
#       <td id="T_fa706_row1_col1" class="data row1 col1" >61.12±.38</td>
#       <td id="T_fa706_row1_col2" class="data row1 col2" >81.71±.06</td>
#       <td id="T_fa706_row1_col3" class="data row1 col3" >47.87±.34</td>
#       <td id="T_fa706_row1_col4" class="data row1 col4" >69.06±.90</td>
#     </tr>
#     <tr>
#       <th id="T_fa706_level0_row2" class="row_heading level0 row2" >Ground Truth</th>
#       <td id="T_fa706_row2_col0" class="data row2 col0" >94.58±.27</td>
#       <td id="T_fa706_row2_col1" class="data row2 col1" >nan±nan</td>
#       <td id="T_fa706_row2_col2" class="data row2 col2" >nan±nan</td>
#       <td id="T_fa706_row2_col3" class="data row2 col3" >71.43±.13</td>
#       <td id="T_fa706_row2_col4" class="data row2 col4" >nan±nan</td>
#     </tr>
#     <tr>
#       <th id="T_fa706_level0_row3" class="row_heading level0 row3" >KSWIN</th>
#       <td id="T_fa706_row3_col0" class="data row3 col0" >94.23±.55</td>
#       <td id="T_fa706_row3_col1" class="data row3 col1" >70.10±1.98</td>
#       <td id="T_fa706_row3_col2" class="data row3 col2" >83.01±.06</td>
#       <td id="T_fa706_row3_col3" class="data row3 col3" >71.38±.16</td>
#       <td id="T_fa706_row3_col4" class="data row3 col4" >73.13±.31</td>
#     </tr>
#     <tr>
#       <th id="T_fa706_level0_row4" class="row_heading level0 row4" >OneTailedADWIN</th>
#       <td id="T_fa706_row4_col0" class="data row4 col0" >94.25±.38</td>
#       <td id="T_fa706_row4_col1" class="data row4 col1" >70.22±2.58</td>
#       <td id="T_fa706_row4_col2" class="data row4 col2" >82.64±.20</td>
#       <td id="T_fa706_row4_col3" class="data row4 col3" >71.25±.15</td>
#       <td id="T_fa706_row4_col4" class="data row4 col4" >73.00±.50</td>
#     </tr>
#     <tr>
#       <th id="T_fa706_level0_row5" class="row_heading level0 row5" >P-KSWIN</th>
#       <td id="T_fa706_row5_col0" class="data row5 col0" >93.86±.48</td>
#       <td id="T_fa706_row5_col1" class="data row5 col1" >70.30±1.07</td>
#       <td id="T_fa706_row5_col2" class="data row5 col2" >83.03±.24</td>
#       <td id="T_fa706_row5_col3" class="data row5 col3" >71.17±.12</td>
#       <td id="T_fa706_row5_col4" class="data row5 col4" >73.23±.49</td>
#     </tr>
#   </tbody>
# </table>
